# %%
# 인터렉티브 그래프
## plotly와 plotly express

# %%
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
# 참고 : nbformat 패키지는 vscode 쥬피터 노트북 환경에서 plotly 그래프를 화면에 그려준다.
# pip install nbformat (4.2.0 이상) 설치 후 프로그램 재실해 후 동작함.

# %%
# 설치확인
import plotly
plotly.__version__
# Out:
# '6.9.0'

# %%
## 간단한 데이터 생성
data = {
    'x' : [1,2,3,4],
    'y' : [10,11,12,13]
}

# %%
# 선 그래프 생성
fig = px.line(data, x='x', y='y', title='첫 번째 plotly 그래프')
fig.show()
