# %% [markdown]
# # Streamlit 이란?
# # pip install streamli
# # 첫 번째 Streamlit 애프리케이션 만들기

# %%
# %%writefile my_first_app.py
import streamlit as st

st.title('안녕하세요 Streamlit')
st.write(' 나의 첫 번째 Streamlit 애플리케이션입니다.')
# Out:
# Overwriting my_first_app.py

# %%
#!streamlit run my_first_app.py
# Out:
# ^C
