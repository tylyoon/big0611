# %%
print("Hello")
# Out:
# Hello

# %%
a = 10
b = 3
print(a + b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)
# Out:
# 13
# 3.3333333333333335
# 3
# 1
# 1000

# %% [markdown]
# 2. 비교연산자

# %%
#### 3. 논리연산자

# %%
print((10>5) and (3<1))
print((10>5) or (3>1) and (4<1))
print(not(10<5))
# Out:
# False
# True
# True

# %% [markdown]
# 4. 대입연산자

# %%
x = 5
a = b

# %% [markdown]
# 5.복합 대입 연산자

# %%
x = 5
x += 3
print(x)
x -= 3
print(x)
x *= 3
print(x)
x /= 3
print(x)
x //= 3
print(x)
x %= 3
print(x)
x **= 3
print(x)
# Out:
# 8
# 5
# 15
# 5.0
# 1.0
# 1.0
# 1.0

# %% [markdown]
# 5. 멤버십 연산자
# - in: 값이 안에 있으면 True
# - not in: 값이 안에 없으면 True

# %%
fruits = ["apple","banana","cherry"]b
print(fruits)
print(type(fruits))
print(fruits[2])
print("apple" in fruits)
print("orange" in fruits)
# Out:
# ['apple', 'banana', 'cherry']
# <class 'list'>
# cherry
# True
# False

# %% [markdown]
# 정수와 실수 연산

# %%
a = 5
b = 5.0
c = 10
a + b
c = a + b
print(c)
# Out:
# 10.0
